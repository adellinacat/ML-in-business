# %% [markdown]
# #### Пользовательская сторона

# %%
import requests

import urllib.request
import json

# %%
# Пример данных
data = ( 
    "Play with kids, get paid for it.Vacancies in Asia$1500 USD + monthly ($200 Cost of living)Housing providedAirfare ReimbursedExcellent for student loans/credit cardsGabriel Adkins (#URL_ed9094c60184b8a4975333957f05be37e69d3cdb68decc9dd9a4242733cfd7f7#)#URL_75db76d58f7994c7db24e8998c2fc953ab9a20ea9ac948b217693963f78d2e6b#We are looking for friendly people. If you do not plan to take part in a 3-5 minute interview, kindly do not waste your time applying :-)",
    "We help teachers get safe &amp; secure jobs abroad :)",
    "0"
)

# %%
# формируем запрос
def send_json(x):
    description, company_profile, benefits = x
    
    body = {
        'description': description, 
        'company_profile': company_profile,
        'benefits': benefits
        }
    myurl = 'http://127.0.0.1:5000' + '/predict'
    headers = {'content-type': 'application/json; charset=utf-8'}
    response = requests.post(myurl, json=body, headers=headers)
    return response.json()['predictions']

# %%
# обращение к серверу с запросом из одного набора 
response = send_json(data)
print('предсказание', response)
# Out:
# предсказание 0.008697720401471048

# %%
# Пример данных 2
data = (
    "Stylect is a dynamic startup that helps helps women discover and buy shoes. We’re a small team based in London that has previously worked at Google, Techstars, Pixelmator and Rocket Internet.We place a high premium on simplicity no matter what we’re working on (i.e. design, programming, marketing). We’re also a team that ships fast. We built version 1 of our app in a week, the next release (built in a month) was featured in the Apple Appstore Italy as a best new fashion app. Fast release cycles are challenging, but also very fun - which is why we love them.\xa0As we’ve grown, the projects that we’re working on have grown both in scale and in technical complexity. \xa0Stylect is looking for someone who can help us improve our backend which gathers product data; analyses/categorizes it; and shows it to thousands of users daily. Each step in the process has unique challenges that demands a strong technical background.",
    "ustwo offers you the opportunity to be yourself, whilst delivering the best work on the planet for some of the biggest and most innovative brands. A culture thriving on collaboration underpins what is an amazing work smart/ live well environment.We genuinely care about the work that we deliver and the people who help make it all possible. We only invest in projects, people and practices that we believe in, to ensure we remain excited about every opportunity.",
    "We are negotiable on salary and there is the potential for equity for the right candidate."
)

# %%
# обращение к серверу с запросом из одного набора 
response = send_json(data)
print('предсказание', response)
# Out:
# предсказание 0.0013539117062165288

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.metrics import f1_score
from urllib import request, parse


X_test = pd.read_csv("X_test.csv")
y_test = pd.read_csv("y_test.csv")
X_test = X_test.fillna('0')

# %%
X_test.head(10)
# Out:
#    job_id                                           title  \
# 0    4709                                 Python Engineer
# 1   11080                               Entry Level Sales
# 2   12358                           Agile Project Manager
# 3   14512                           Marketing Coordinator
# 4   16692                         Full-stack Web Engineer
# 5    1412                              BigData Consultant
# 6    8516  Customer Care Agent (Night Shift with Spanish)
# 7    4990         English Teacher Abroad (Conversational)
# 8     362                      Junior System Test Analyst
# 9    8251                               Head of Community
#
#                 location          department salary_range  \
# 0           GB, , London                   0            0
# 1     US, OH, Cincinnati                   0  55000-75000
# 2       US, NY, New York                   0            0
# 3        GB, GBN, London  Business:Marketing            0
# 4  US, CA, San Francisco                   0            0
# 5       US, CA, Campbell                   0            0
# 6                 IE, ,                    0            0
# 7         US, MN, Duluth                   0            0
# 8        GB, CMD, London          Technology  19000-19000
# 9        GB, LND, London                   0            0
#
#                                      company_profile  \
# 0                                                  0
# 1                                                  0
# 2  ustwo offers you the opportunity to be yoursel...
# 3  We build software for fashion retailers, to he...
# 4  Runscope is building tools for developers work...
# 5  Innovative Data Science Solutions Insights, Pu...
# 6  ding* is the world’s largest top-up provider. ...
# 7  We help teachers get safe &amp; secure jobs ab...
# 8  The Technical Team and offering at VML London ...
# 9  Seedcamp is Europe's leading micro-seed invest...
#
#                                          description  \
# 0  Stylect is a dynamic startup that helps helps ...
# 1  General Summary: Achieves maximum sales profit...
# 2  At ustwo™ you get to be yourself, whilst deliv...
# 3  About EDITDEDITD runs the world's biggest appa...
# 4  As a Web Engineer at Runscope you'll be respon...
# 5  About the Job:&nbsp;&nbsp;&nbsp;This is a key ...
# 6  Customer Care Agent (Night Shift with Spanish)...
# 7  Play with kids, get paid for it.Vacancies in A...
# 8  At VML, testing is an integral part of our sof...
# 9  The JobBuild relationships with the mentor, in...
#
#                                         requirements  \
# 0  We don’t care where you studied or what your G...
# 1                                                  0
# 2  Skills• Experience interfacing directly with c...
# 3  Required Skills / Experience:Ability to analys...
# 4  Extensive front-end web experience (HTML/CSS/J...
# 5  Basic/Minimum Job QualificationsStrong hands o...
# 6                                                  0
# 7  University degree required. TEFL / TESOL / CEL...
# 8  Execute requirements based manual test casesCo...
# 9                                                  0
#
#                                             benefits  telecommuting  \
# 0  We are negotiable on salary and there is the p...              0
# 1  Great Health and DentalFast Advancement Opport...              1
# 2                                                  0              0
# 3                                                  0              0
# 4  Be a part of an experienced team who have work...              0
# 5                                                  0              0
# 6                                                  0              0
# 7                                See job description              0
# 8                                                  0              0
# 9                                                  0              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0       Full-time         Entry level
# 1                 0              0       Full-time         Entry level
# 2                 1              0               0                   0
# 3                 1              0       Full-time                   0
# 4                 1              1       Full-time    Mid-Senior level
# 5                 1              1               0                   0
# 6                 1              1       Full-time                   0
# 7                 1              1        Contract         Entry level
# 8                 1              1       Full-time           Associate
# 9                 1              0       Full-time      Not Applicable
#
#           required_education                          industry  \
# 0                Unspecified                 Apparel & Fashion
# 1  High School or equivalent                Financial Services
# 2                          0                                 0
# 3                          0                                 0
# 4                          0                                 0
# 5                          0                                 0
# 6                          0                Telecommunications
# 7          Bachelor's Degree              Education Management
# 8          Bachelor's Degree         Marketing and Advertising
# 9                Unspecified  Venture Capital & Private Equity
#
#                  function  fraudulent
# 0  Information Technology           0
# 1                   Sales           0
# 2                       0           0
# 3               Marketing           0
# 4             Engineering           0
# 5                       0           0
# 6        Customer Service           0
# 7               Education           0
# 8             Engineering           0
# 9                   Other           0

# %%
X_test.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count   5901.000000    5901.000000       5901.000000    5901.000000
# mean    8925.978309       0.043044          0.783596       0.499407
# std     5147.272513       0.202972          0.411828       0.500042
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.000000       0.000000          1.000000       0.000000
# 50%     8903.000000       0.000000          1.000000       0.000000
# 75%    13345.000000       0.000000          1.000000       1.000000
# max    17879.000000       1.000000          1.000000       1.000000
#
#         fraudulent
# count  5901.000000
# mean      0.050669
# std       0.219340
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
import numpy as np
X_test = X_test[~X_test.isin([np.nan, np.inf, -np.inf]).any(1)]

# %% [markdown]
# Передаем запрос одиночный из наших данных и посмотрим на ответ

# %%
response = send_json(X_test[['description', 'company_profile', 'benefits']].iloc[0,:])

# %%
X_test[['description', 'company_profile', 'benefits']].head()
# Out:
#                                          description  \
# 0  Stylect is a dynamic startup that helps helps ...
# 1  General Summary: Achieves maximum sales profit...
# 2  At ustwo™ you get to be yourself, whilst deliv...
# 3  About EDITDEDITD runs the world's biggest appa...
# 4  As a Web Engineer at Runscope you'll be respon...
#
#                                      company_profile  \
# 0                                                  0
# 1                                                  0
# 2  ustwo offers you the opportunity to be yoursel...
# 3  We build software for fashion retailers, to he...
# 4  Runscope is building tools for developers work...
#
#                                             benefits
# 0  We are negotiable on salary and there is the p...
# 1  Great Health and DentalFast Advancement Opport...
# 2                                                  0
# 3                                                  0
# 4  Be a part of an experienced team who have work...

# %%
N = 50

# %%
# %%time
predictions = X_test[
                     ['description', 'company_profile', 'benefits']
                     ].iloc[:N].apply(lambda x: send_json(x), axis=1)
# Out:
# CPU times: total: 141 ms
# Wall time: 1.43 s

# %%
predictions.values[:5]
# Out:
# array([0.02617387, 0.04457579, 0.00480416, 0.0010568 , 0.00122864])

# %%
y_test.head()
# Out:
#    fraudulent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
import numpy as np

precision, recall, thresholds = precision_recall_curve(y_test[:N], predictions)

fscore = (2 * precision * recall) / (precision + recall)

ix = np.argmax(fscore)
print(f'Best Threshold={thresholds[ix]}, F-Score={fscore[ix]:.3f}, Precision={precision[ix]:.3f}, Recall={recall[ix]:.3f}')
# Out:
# Best Threshold=0.9078009371449137, F-Score=0.667, Precision=1.000, Recall=0.500

# %%
roc_auc_score(y_score=predictions.values, y_true=y_test.values[:N])
# Out:
# 0.9270833333333333
